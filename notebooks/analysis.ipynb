# %% [markdown]
# # Analysis of experiment: mlp-nsplits-10

# %%
import pandas as pd
import numpy as np

from exps.plots import speedup_plots

# %%
df_paper = pd.read_parquet("../data-paper/mlp-nsplits-10.parquet.gzip")
df = pd.read_parquet("../data/mlp-nsplits-10.parquet")

# %%
# Setup
y = "metric:roc_auc_ovr [0.0, 1.0] (maximize)"
baseline = "disabled"
test_y = "summary:test_bagged_roc_auc_ovr" # Not used
method_col = "setting:cv_early_stop_strategy"
fold = "setting:fold"
dataset = "setting:task"
x = "reported_at"
x_start = "created_at"
x_label = "Time (s)"

# %%
# Paper
table_full, table_summary = speedup_plots(
    df_paper,
    y=y,
    baseline=baseline,
    test_y=test_y,
    method=method_col,
    fold=fold,
    dataset=dataset,
    x=x,
    x_start=x_start,
    x_label=x_label,
)
# Out:
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %%
# My results
table_full2, table_summary2 = speedup_plots(
    df,
    y=y,
    baseline=baseline,
    test_y=test_y,
    method=method_col,
    fold=fold,
    dataset=dataset,
    x=x,
    x_start=x_start,
    x_label=x_label,
)
# Out:
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((0.17254901960784313, 0.6274509803921569, 0.17254901960784313)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# /Users/artem/Desktop/study/cs/y3/dissertation_project/DontWasteYourTime-early-stopping/src/exps/plots.py:1280: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %%
table_summary
# Out:
#                  Average Speedup \%   Datasets Failed
# Method
# Aggresive  $\textbf{301.0\pm187.0}$          $20 /36$
# Forgiving            $174.0\pm64.0$  $\textbf{0} /36$

# %%
table_full
# Out:
# Method                       Aggresive Forgiving
# Dataset (OpenML Task ID)
# 146818                    \textbf{---}   111.0\%
# 146820                    \textbf{---}   113.0\%
# 168350                         219.0\%   162.0\%
# 168757                    \textbf{---}   229.0\%
# 168784                    \textbf{---}   136.0\%
# 168910                         272.0\%   194.0\%
# 168911                         143.0\%   111.0\%
# 189922                         375.0\%   283.0\%
# 190137                    \textbf{---}    94.0\%
# 190146                    \textbf{---}   197.0\%
# 190392                         881.0\%   204.0\%
# 190410                         284.0\%   151.0\%
# 190411                    \textbf{---}   115.0\%
# 190412                         157.0\%   195.0\%
# 359953                         391.0\%   271.0\%
# 359954                         156.0\%   141.0\%
# 359955                    \textbf{---}   107.0\%
# 359956                    \textbf{---}   142.0\%
# 359957                         166.0\%   117.0\%
# 359958                    \textbf{---}   126.0\%
# 359959                    \textbf{---}   165.0\%
# 359960                         499.0\%   310.0\%
# 359961                         255.0\%   136.0\%
# 359962                    \textbf{---}   173.0\%
# 359963                    \textbf{---}   118.0\%
# 359964                    \textbf{---}   183.0\%
# 359965                    \textbf{---}   128.0\%
# 359967                    \textbf{---}   183.0\%
# 359968                    \textbf{---}   263.0\%
# 359969                    \textbf{---}   259.0\%
# 359970                         259.0\%   185.0\%
# 359971                         258.0\%   321.0\%
# 359972                         124.0\%   112.0\%
# 359973                    \textbf{---}   124.0\%
# 359975                    \textbf{---}   132.0\%
# 359979                         386.0\%   268.0\%

# %%
table_summary2
# Out:
#                  Average Speedup \%   Datasets Failed
# Method
# Aggresive  $\textbf{282.0\pm164.0}$          $18 /36$
# Forgiving            $172.0\pm64.0$  $\textbf{1} /36$

# %%
table_full2
# Out:
# Method                       Aggresive     Forgiving
# Dataset (OpenML Task ID)
# 146818                    \textbf{---}       139.0\%
# 146820                    \textbf{---}       121.0\%
# 168350                         213.0\%       187.0\%
# 168757                          88.0\%       229.0\%
# 168784                    \textbf{---}       116.0\%
# 168910                         419.0\%       254.0\%
# 168911                         137.0\%  \textbf{---}
# 189922                         302.0\%       208.0\%
# 190137                    \textbf{---}       100.0\%
# 190146                    \textbf{---}       252.0\%
# 190392                         716.0\%       400.0\%
# 190410                         274.0\%       164.0\%
# 190411                    \textbf{---}       152.0\%
# 190412                    \textbf{---}       148.0\%
# 359953                         284.0\%       164.0\%
# 359954                    \textbf{---}       104.0\%
# 359955                    \textbf{---}       114.0\%
# 359956                    \textbf{---}       104.0\%
# 359957                         201.0\%       141.0\%
# 359958                    \textbf{---}       109.0\%
# 359959                    \textbf{---}       114.0\%
# 359960                         470.0\%       250.0\%
# 359961                         312.0\%       165.0\%
# 359962                    \textbf{---}       152.0\%
# 359963                         105.0\%       123.0\%
# 359964                    \textbf{---}       215.0\%
# 359965                         148.0\%       133.0\%
# 359967                    \textbf{---}       159.0\%
# 359968                    \textbf{---}       172.0\%
# 359969                         100.0\%       226.0\%
# 359970                         313.0\%       176.0\%
# 359971                         417.0\%       189.0\%
# 359972                         144.0\%       113.0\%
# 359973                    \textbf{---}       169.0\%
# 359975                    \textbf{---}       152.0\%
# 359979                         434.0\%       302.0\%

# %% [markdown]
# ## Paper results
# ### Summary
# | Method    | Average Speedup \%       | Datasets Failed   |
# |:----------|:-------------------------|:------------------|
# | Aggresive | $301.0\pm187.0$ | $20 /36$          |
# | Forgiving | $174.0\pm64.0$           | $0 /36$  |
#
# ### Full
# |   Dataset (OpenML Task ID) | Aggresive    | Forgiving   |
# |---------------------------:|:-------------|:------------|
# |                     146818 | --- | 111.0\%     |
# |                     146820 | --- | 113.0\%     |
# |                     168350 | 219.0\%      | 162.0\%     |
# |                     168757 | --- | 229.0\%     |
# |                     168784 | --- | 136.0\%     |
# |                     168910 | 272.0\%      | 194.0\%     |
# |                     168911 | 143.0\%      | 111.0\%     |
# |                     189922 | 375.0\%      | 283.0\%     |
# |                     190137 | --- | 94.0\%      |
# |                     190146 | --- | 197.0\%     |
# |                     190392 | 881.0\%      | 204.0\%     |
# |                     190410 | 284.0\%      | 151.0\%     |
# |                     190411 | --- | 115.0\%     |
# |                     190412 | 157.0\%      | 195.0\%     |
# |                     359953 | 391.0\%      | 271.0\%     |
# |                     359954 | 156.0\%      | 141.0\%     |
# |                     359955 | --- | 107.0\%     |
# |                     359956 | --- | 142.0\%     |
# |                     359957 | 166.0\%      | 117.0\%     |
# |                     359958 | --- | 126.0\%     |
# |                     359959 | --- | 165.0\%     |
# |                     359960 | 499.0\%      | 310.0\%     |
# |                     359961 | 255.0\%      | 136.0\%     |
# |                     359962 | --- | 173.0\%     |
# |                     359963 | --- | 118.0\%     |
# |                     359964 | --- | 183.0\%     |
# |                     359965 | --- | 128.0\%     |
# |                     359967 | --- | 183.0\%     |
# |                     359968 | --- | 263.0\%     |
# |                     359969 | --- | 259.0\%     |
# |                     359970 | 259.0\%      | 185.0\%     |
# |                     359971 | 258.0\%      | 321.0\%     |
# |                     359972 | 124.0\%      | 112.0\%     |
# |                     359973 | --- | 124.0\%     |
# |                     359975 | --- | 132.0\%     |
# |                     359979 | 386.0\%      | 268.0\%     |

# %% [markdown]
# ## My results
# ### Summary
# | Method    | Average Speedup \%       | Datasets Failed   |
# |:----------|:-------------------------|:------------------|
# | Aggresive | $282.0\pm164.0$ | $18 /36$          |
# | Forgiving | $172.0\pm64.0$           | $1 /36$  |
#
# ### Full
# |   Dataset (OpenML Task ID) | Aggresive    | Forgiving    |
# |---------------------------:|:-------------|:-------------|
# |                     146818 | --- | 139.0\%      |
# |                     146820 | --- | 121.0\%      |
# |                     168350 | 213.0\%      | 187.0\%      |
# |                     168757 | 88.0\%       | 229.0\%      |
# |                     168784 | --- | 116.0\%      |
# |                     168910 | 419.0\%      | 254.0\%      |
# |                     168911 | 137.0\%      | --- |
# |                     189922 | 302.0\%      | 208.0\%      |
# |                     190137 | --- | 100.0\%      |
# |                     190146 | --- | 252.0\%      |
# |                     190392 | 716.0\%      | 400.0\%      |
# |                     190410 | 274.0\%      | 164.0\%      |
# |                     190411 | --- | 152.0\%      |
# |                     190412 | --- | 148.0\%      |
# |                     359953 | 284.0\%      | 164.0\%      |
# |                     359954 | --- | 104.0\%      |
# |                     359955 | --- | 114.0\%      |
# |                     359956 | --- | 104.0\%      |
# |                     359957 | 201.0\%      | 141.0\%      |
# |                     359958 | --- | 109.0\%      |
# |                     359959 | --- | 114.0\%      |
# |                     359960 | 470.0\%      | 250.0\%      |
# |                     359961 | 312.0\%      | 165.0\%      |
# |                     359962 | --- | 152.0\%      |
# |                     359963 | 105.0\%      | 123.0\%      |
# |                     359964 | --- | 215.0\%      |
# |                     359965 | 148.0\%      | 133.0\%      |
# |                     359967 | --- | 159.0\%      |
# |                     359968 | --- | 172.0\%      |
# |                     359969 | 100.0\%      | 226.0\%      |
# |                     359970 | 313.0\%      | 176.0\%      |
# |                     359971 | 417.0\%      | 189.0\%      |
# |                     359972 | 144.0\%      | 113.0\%      |
# |                     359973 | --- | 169.0\%      |
# |                     359975 | --- | 152.0\%      |
# |                     359979 | 434.0\%      | 302.0\%      |
